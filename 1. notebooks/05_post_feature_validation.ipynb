# %% [markdown]
# Post Feature Validation Workflow
#
# 1. Validation Objective & Scope
# 2. Schema Review (new features only)
# 3. Null & Range Validation
# 4. Distribution Sanity Checks
# 5. Redundancy & Logic Review
# 6. Validation Summary
#
#
# It is not EDA again.
# It is quality assurance for engineered features.

# %% [markdown]
# ---
#
# # **Validation Objective & Scope**
#
# ---
#
#
# The objective of this step is to perform sanity and consistency checks on engineered features to ensure logical correctness and analytical readiness.
#
# Given that feature engineering introduced rule-based and interpretable variables without aggregation or transformation, this validation is limited to lightweight structural and distribution checks rather than full exploratory analysis.

# %%
#Dependencies
import pandas as pd

# %% [markdown]
# ---
#
# # **Schema Review**
#
# ---

# %%
df = pd.read_csv('../data/final/consumer_final_data.csv')

df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount  \
# 0            1   55   Male         Blouse  Clothing               53
# 1            2   19   Male        Sweater  Clothing               64
# 2            3   50   Male          Jeans  Clothing               73
# 3            4   21   Male        Sandals  Footwear               90
# 4            5   45   Male         Blouse  Clothing               49
#
#         location size      color  season  ...  discount_applied  \
# 0       Kentucky    L       Gray  Winter  ...              True
# 1          Maine    L     Maroon  Winter  ...              True
# 2  Massachusetts    S     Maroon  Spring  ...              True
# 3   Rhode Island    M     Maroon  Spring  ...              True
# 4         Oregon    M  Turquoise  Spring  ...              True
#
#   previous_purchases payment_method  frequency_of_purchases  \
# 0                 14          Venmo             Fortnightly
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   customer_id                  3900 non-null   int64
#  1   age                          3900 non-null   int64
#  2   gender                       3900 non-null   object
#  3   item_purchased               3900 non-null   object
#  4   category                     3900 non-null   object
#  5   purchase_amount              3900 non-null   int64
#  6   location                     3900 non-null   object
#  7   size                         3900 non-null   object
#  8   color                        3900 non-null   object
#  9   season                       3900 non-null   object
#  10  review_rating                3900 non-null   float64
#  11  subscription_status          3900 non-null   object
#  12  shipping_type                3900 non-null   object
# ...

# %% [markdown]
# Schema review confirms the successful introduction of engineered features and alignment with expected data types.

# %% [markdown]
# ---
#
# # **Null & Range Validation**
#
# ---
#
# Ensure no unintended missing values were introduced.

# %%
df[
    [
        "age_group",
        "high_value_transaction_flag",
        "promotion_exposure_flag",
        "express_shipping_flag",
        "purchase_frequency_days"
    ]
].isna().sum()
# Out:
# age_group                      0
# high_value_transaction_flag    0
# promotion_exposure_flag        0
# express_shipping_flag          0
# purchase_frequency_days        0
# dtype: int64

# %% [markdown]
# Null checks were performed on engineered features to verify that feature creation did not introduce unintended missing values.

# %% [markdown]
# ---
#
# # **Distribution Sanity Checks**
#
# ---
#
# Distribution Sanity Checks

# %%
df["high_value_transaction_flag"].value_counts()
# Out:
# high_value_transaction_flag
# 0    1986
# 1    1914
# Name: count, dtype: int64

# %%
df["promotion_exposure_flag"].value_counts()
# Out:
# promotion_exposure_flag
# 0    2223
# 1    1677
# Name: count, dtype: int64

# %%
df["express_shipping_flag"].value_counts()
# Out:
# express_shipping_flag
# 0    2606
# 1    1294
# Name: count, dtype: int64

# %%
df["age_group"].value_counts()
# Out:
# age_group
# Teen           1028
# Adult           986
# Senior          944
# Young Adult     942
# Name: count, dtype: int64

# %% [markdown]
# Value distribution checks confirm that engineered categorical and binary features fall within expected logical ranges.

# %% [markdown]
# ---
#
# # **Redundancy & Logic Review**
#
# ---
#
# Confirm no duplicate or overlapping features remain.

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'purchase_outlier_flag', 'age_group',
#        'high_value_transaction_flag', 'promotion_exposure_flag',
#        'express_shipping_flag', 'purchase_frequency_days'],
#       dtype='object')

# %% [markdown]
# Feature review confirms removal of redundant promotional indicators and consolidation into a single promotional exposure feature.

# %% [markdown]
# ---
#
# # **Validation Summary**
#
# ---
#
# Post-feature validation confirms that engineered features are logically consistent, free from unintended missing values, and aligned with expected business definitions.
#
# Given the rule-based and interpretable nature of the features introduced, no further exploratory analysis is required at this stage. The dataset is deemed suitable for downstream SQL analysis and dashboard development.

# %% [markdown]
# ---
#
# # **Note on Post-Feature Exploratory Analysis**
#
# ---
#
# A full post-feature exploratory data analysis was not performed, as the engineered features are deterministic, rule-based transformations of existing attributes rather than complex statistical or model-driven constructs.
#
# Accordingly, lightweight validation checks were sufficient to confirm feature correctness and analytical readiness.

# %% [markdown]
# ---
#
# # **Next Steps & Assumptions**
#
# ---
#
# Subsequent steps will focus on:
#
# - SQL Business Queries
# - Dashboarding in PowerBI
